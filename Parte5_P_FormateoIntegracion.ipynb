# %% [markdown]
# <center><img src="http://alacip.org/wp-content/uploads/2014/03/logoEscalacip1.png" width="500"></center>
#
#
# <center> <h1>Curso: Introducción al Python</h1> </center>
#
# <br></br>
#
# * Profesor:  <a href="http://www.pucp.edu.pe/profesor/jose-manuel-magallanes/" target="_blank">Dr. José Manuel Magallanes, PhD</a> ([jmagallanes@pucp.edu.pe](mailto:jmagallanes@pucp.edu.pe))<br>
#     - Profesor del **Departamento de Ciencias Sociales, Pontificia Universidad Católica del Peru**.<br>
#     - Senior Data Scientist del **eScience Institute** and Visiting Professor at **Evans School of Public Policy and Governance, University of Washington**.<br>
#     - Fellow Catalyst, **Berkeley Initiative for Transparency in Social Sciences, UC Berkeley**.
#
#
# ## Parte 5:  Formateando Valores en Python

# %% [markdown]
# <a id='beginning'></a>
#
# Una vez que los datos han sido limpiados, es momento de ver si tienen el formato para ser tratados estadísticamente, es decir, que representan el correcto tipo de [escala](#scale) y que representen una adecuada [monotonía](#monotony).

# %% [markdown]
# Traigamos unos datos conocidos, pero acelerando la limpieza:

# %%
wikiLink="https://en.wikipedia.org/wiki/List_of_freedom_indices" 

#traer tabla
import pandas as pd
DF=pd.read_html(wikiLink,header=0,flavor='bs4',attrs={'class': 'wikitable sortable',})[0]

#limpiando celdas
import re  
pattern='\\s+|\\d+|\\[|\\]'
nothing=''
DF.columns=[re.sub(pattern,nothing,element) for element in DF.columns]
DF.head()
# Out:
#        Country FreedomintheWorld IndexofEconomicFreedom  \
# 0  Afghanistan          not free          mostly unfree
# 1      Albania       partly free        moderately free
# 2      Algeria          not free              repressed
# 3      Andorra              free                    NaN
# 4       Angola          not free          mostly unfree
#
#         PressFreedomIndex        DemocracyIndex
# 0     difficult situation  authoritarian regime
# 1     noticeable problems         hybrid regime
# 2     difficult situation  authoritarian regime
# 3  satisfactory situation                   NaN
# 4     noticeable problems  authoritarian regime

# %% [markdown]
# ____
# <a id='scale'></a>
#
# ### Las escalas de medición
#
# Para saber si están en la escala correcta, debemos usar _dtypes_:

# %%
DF.dtypes
# Out:
# Country                   object
# FreedomintheWorld         object
# IndexofEconomicFreedom    object
# PressFreedomIndex         object
# DemocracyIndex            object
# dtype: object

# %% [markdown]
# Los cuatro indices son categorías, no texto (_object_). Hagamos la conversión:

# %%
headers=DF.columns
DF[headers[1:]]=DF[headers[1:]].astype('category')

# %%
# sale:
DF.dtypes
# Out:
# Country                     object
# FreedomintheWorld         category
# IndexofEconomicFreedom    category
# PressFreedomIndex         category
# DemocracyIndex            category
# dtype: object

# %% [markdown]
# Este cambio es imperceptible a la vista:

# %%
DF.head()
# Out:
#        Country FreedomintheWorld IndexofEconomicFreedom  \
# 0  Afghanistan          not free          mostly unfree
# 1      Albania       partly free        moderately free
# 2      Algeria          not free              repressed
# 3      Andorra              free                    NaN
# 4       Angola          not free          mostly unfree
#
#         PressFreedomIndex        DemocracyIndex
# 0     difficult situation  authoritarian regime
# 1     noticeable problems         hybrid regime
# 2     difficult situation  authoritarian regime
# 3  satisfactory situation                   NaN
# 4     noticeable problems  authoritarian regime

# %% [markdown]
# Ahora si podemos saber sus valores:

# %%
DF.FreedomintheWorld.cat.categories
# Out:
# Index(['free', 'not free', 'partly free'], dtype='object')

# %%
DF.IndexofEconomicFreedom.cat.categories
# Out:
# Index(['free', 'moderately free', 'mostly free', 'mostly unfree', 'repressed'], dtype='object')

# %%
DF.PressFreedomIndex.cat.categories
# Out:
# Index(['difficult situation', 'good situation', 'noticeable problems',
#        'satisfactory situation', 'very serious situation'],
#       dtype='object')

# %%
DF.DemocracyIndex.cat.categories
# Out:
# Index(['authoritarian regime', 'flawed democracy', 'full democracy',
#        'hybrid regime'],
#       dtype='object')

# %% [markdown]
# Vemos que tenemos hasta 5 niveles en 2 variables, y 3 y 4 niveles en otras. De ahi que lo prudente es encontrar la distribución común de valores que refleja la ordinalidad, y los máximos y mínimos.
#
# Veamos como volverla ordinal. Primero los valores:

# %%
oldFree=list(DF.FreedomintheWorld.cat.categories)
newFree=['very good','very bad','middle']
recodeFree={old:new for old,new in zip (oldFree,newFree)}

oldEco=list(DF.IndexofEconomicFreedom.cat.categories)
newEco=['very good','middle','good','bad','very bad']
recodeEco={old:new for old,new in zip (oldEco,newEco)}


oldPress=list(DF.PressFreedomIndex.cat.categories)
newPress=['bad','very good','middle','good','very bad']
recodePress={old:new for old,new in zip (oldPress,newPress)}

oldDemo=list(DF.DemocracyIndex.cat.categories)
newDemo=['very bad','good','very good','bad']
recodeDemo={old:new for old,new in zip (oldDemo,newDemo)}

# %% [markdown]
# Ahora usamos los dicts creado para recodificar:

# %%
DF.FreedomintheWorld.cat.rename_categories(recodeFree,inplace=True)

DF.IndexofEconomicFreedom.cat.rename_categories(recodeEco,inplace=True)

DF.PressFreedomIndex.cat.rename_categories(recodePress,inplace=True)

DF.DemocracyIndex.cat.rename_categories(recodeDemo,inplace=True)

# veamos:
DF
# Out:
#                     Country FreedomintheWorld IndexofEconomicFreedom  \
# 0               Afghanistan          very bad                    bad
# 1                   Albania            middle                 middle
# 2                   Algeria          very bad               very bad
# 3                   Andorra         very good                    NaN
# 4                    Angola          very bad                    bad
# 5       Antigua and Barbuda         very good                    NaN
# 6                 Argentina         very good                    bad
# 7                   Armenia            middle                 middle
# 8                 Australia         very good              very good
# 9                   Austria         very good                   good
# 10               Azerbaijan          very bad                 middle
# 11                  Bahamas         very good                 middle
# 12                  Bahrain          very bad                 middle
# 13               Bangladesh            middle                    bad
# 14                 Barbados         very good                 middle
# 15                  Belarus          very bad                    bad
# 16                  Belgium         very good                 middle
# 17                   Belize         very good                    bad
# 18                    Benin         very good                    bad
# 19                   Bhutan            middle                 middle
# 20                  Bolivia            middle               very bad
# 21   Bosnia and Herzegovina            middle                 middle
# 22                 Botswana         very good                 middle
# 23                   Brazil         very good                    bad
# 24                   Brunei          very bad                 middle
# 25                 Bulgaria         very good                 middle
# 26             Burkina Faso            middle                    bad
# 27                    Burma            middle                    bad
# 28                  Burundi          very bad               very bad
# 29                 Cambodia          very bad                    bad
# ..                      ...               ...                    ...
# 175                  Sweden         very good                   good
# 176             Switzerland         very good              very good
# 177                   Syria          very bad                    NaN
# 178                  Taiwan         very good                   good
# 179              Tajikistan          very bad                    bad
# 180                Tanzania            middle                 middle
# 181                Thailand          very bad                 middle
# 182                    Togo            middle                    bad
# 183                   Tonga         very good                    bad
# 184            Transnistria          very bad                    NaN
# 185     Trinidad and Tobago         very good                    bad
# 186                 Tunisia         very good                    bad
# 187                  Turkey          very bad                 middle
# 188            Turkmenistan          very bad               very bad
# 189                  Tuvalu         very good                    NaN
# 190                  Uganda          very bad                    bad
# 191                 Ukraine            middle                    bad
# 192    United Arab Emirates          very bad                   good
# 193          United Kingdom         very good                   good
# 194           United States         very good                   good
# 195                 Uruguay         very good                 middle
# 196              Uzbekistan          very bad                    bad
# 197                 Vanuatu         very good                    bad
# 198               Venezuela          very bad               very bad
# 199                 Vietnam          very bad                    bad
# 200               West Bank          very bad                    NaN
# 201          Western Sahara          very bad                    NaN
# 202                   Yemen          very bad                    NaN
# 203                  Zambia            middle                    bad
# 204                Zimbabwe            middle               very bad
#
#     PressFreedomIndex DemocracyIndex
# 0                 bad       very bad
# 1              middle            bad
# 2                 bad       very bad
# 3                good            NaN
# 4              middle       very bad
# 5              middle            NaN
# 6              middle           good
# 7              middle            bad
# 8                good      very good
# 9                good      very good
# 10           very bad       very bad
# 11             middle            NaN
# 12           very bad       very bad
# 13                bad            bad
# 14             middle            NaN
# 15                bad       very bad
# 16          very good           good
# 17             middle            NaN
# 18             middle            bad
# 19             middle            bad
# 20                bad            bad
# 21             middle            bad
# 22             middle           good
# 23             middle           good
# 24                bad            NaN
# 25                bad           good
# 26               good            bad
# 27                bad       very bad
# 28                bad       very bad
# 29                bad       very bad
# ..                ...            ...
# 175         very good      very good
# 176         very good      very good
# 177          very bad       very bad
# 178              good           good
# 179               bad       very bad
# 180               bad            bad
# 181               bad            bad
# 182            middle       very bad
# 183            middle            NaN
# 184               NaN            NaN
# 185              good           good
# 186            middle           good
# 187               bad            bad
# 188          very bad       very bad
# 189               NaN            NaN
# 190               bad            bad
# 191            middle            bad
# 192               bad       very bad
# 193              good      very good
# 194            middle           good
# 195              good      very good
# 196               bad       very bad
# 197               NaN            NaN
# 198               bad       very bad
# 199          very bad       very bad
# 200               bad            NaN
# 201               NaN            NaN
# 202          very bad       very bad
# 203               bad            bad
# 204               bad       very bad
#
# [205 rows x 5 columns]

# %% [markdown]
# Los datos aun no son ordinales, pero aqui serán:

# %%
from pandas.api.types import CategoricalDtype


ordinal = CategoricalDtype(categories=['very good','good','middle','bad','very bad'],ordered=True)

to_Order=lambda x: x.astype(ordinal)
DF[headers[1:]]=DF[headers[1:]].apply(to_Order)

# %%
# asi va:
DF.head()
# Out:
#        Country FreedomintheWorld IndexofEconomicFreedom PressFreedomIndex  \
# 0  Afghanistan          very bad                    bad               bad
# 1      Albania            middle                 middle            middle
# 2      Algeria          very bad               very bad               bad
# 3      Andorra         very good                    NaN              good
# 4       Angola          very bad                    bad            middle
#
#   DemocracyIndex
# 0       very bad
# 1            bad
# 2       very bad
# 3            NaN
# 4       very bad

# %% [markdown]
# Notemos que las modalidades no usadas están presentes:

# %%
DF.FreedomintheWorld.value_counts(sort=False,dropna=False)
# Out:
# very good    87
# good          0
# middle       62
# bad           0
# very bad     55
# NaN           1
# Name: FreedomintheWorld, dtype: int64

# %% [markdown]
# Verificaciones adicionales:

# %%
#las categorias:
DF.PressFreedomIndex.cat.categories
# Out:
# Index(['very good', 'good', 'middle', 'bad', 'very bad'], dtype='object')

# %%
#tipo de escala?
DF.PressFreedomIndex.cat.ordered
# Out:
# True

# %% [markdown]
# [Go to page beginning](#beginning)
# ____
# <a id='monotony'></a>
#
# ### Cambio de Monotonía:
#
# Verifiquemos si está bien la asignación que hemos hecho:

# %%
DF.PressFreedomIndex.head()
# Out:
# 0       bad
# 1    middle
# 2       bad
# 3      good
# 4    middle
# Name: PressFreedomIndex, dtype: category
# Categories (5, object): [very good < good < middle < bad < very bad]

# %%
DF.PressFreedomIndex.max()
# Out:
# 'very bad'

# %% [markdown]
# Este es un caso donde quiza la intensidad creciente debe ser hacia el sentido positivo del concepto. Claro que pudimos hacerlo al inicio, pero aprovechemos para saber cómo se hace.
#
# Para ello crearé una función:

# %%
def changeMonotony(aColumn):
    # Invierto las categorias:
    newOrder= aColumn.cat.categories[::-1]  # [::-1]  reverses the list.
    # aplico función
    return aColumn.cat.reorder_categories(newOrder,ordered=True)

# %% [markdown]
# Esta función la aplica de nuevo, columna por columna:

# %%
# SOLO UNA VEZ!! (sino reintenta)
DF[headers[1:]]=DF[headers[1:]].apply(changeMonotony)

# %% [markdown]
# ¿Funcionó?

# %%
DF.PressFreedomIndex.head(20)
# Out:
# 0           bad
# 1        middle
# 2           bad
# 3          good
# 4        middle
# 5        middle
# 6        middle
# 7        middle
# 8          good
# 9          good
# 10     very bad
# 11       middle
# 12     very bad
# 13          bad
# 14       middle
# 15          bad
# 16    very good
# 17       middle
# 18       middle
# 19       middle
# Name: PressFreedomIndex, dtype: category
# Categories (5, object): [very bad < bad < middle < good < very good]

# %%
DF.PressFreedomIndex.max()
# Out:
# 'very good'

# %% [markdown]
# Todo lo que hemos trabajado podríamos entregarselo a R para que haga su trabajo estadístico, pero como no tiene metadata, es mejor guardar los indices ordinales como número:

# %%
oldlevels=['very bad','bad','middle','good','very good']
newlevels=[1,2,3,4,5]
recodeLevels={old:new for old,new in zip (oldlevels,newlevels)}

# %%
renamer=lambda column: column.cat.rename_categories(recodeLevels)
DF[headers[1:]]=DF[headers[1:]].apply(renamer)
DF.head(10)
# Out:
#                Country FreedomintheWorld IndexofEconomicFreedom  \
# 0          Afghanistan                 1                    2.0
# 1              Albania                 3                    3.0
# 2              Algeria                 1                    1.0
# 3              Andorra                 5                    NaN
# 4               Angola                 1                    2.0
# 5  Antigua and Barbuda                 5                    NaN
# 6            Argentina                 5                    2.0
# 7              Armenia                 3                    3.0
# 8            Australia                 5                    5.0
# 9              Austria                 5                    4.0
#
#   PressFreedomIndex DemocracyIndex
# 0                 2            1.0
# 1                 3            2.0
# 2                 2            1.0
# 3                 4            NaN
# 4                 3            1.0
# 5                 3            NaN
# 6                 3            4.0
# 7                 3            2.0
# 8                 4            5.0
# 9                 4            5.0

# %% [markdown]
# Un tema adicional son los valores perdidos. Hay varios NaN.
#
# La función para reemplazarlos es sencilla, pero hay que evitar facilismos. Veamos:

# %%
#recordar:
DF.dtypes
# Out:
# Country                     object
# FreedomintheWorld         category
# IndexofEconomicFreedom    category
# PressFreedomIndex         category
# DemocracyIndex            category
# dtype: object

# %%
#tienen que ser numericos:
DF[headers[1:]]=DF[headers[1:]].apply(pd.to_numeric)

# %%
#mediana por grupos: 
DF.groupby(headers[1])[headers[2:]].median()
# Out:
#                    IndexofEconomicFreedom  PressFreedomIndex  DemocracyIndex
# FreedomintheWorld
# 1.0                                   2.0                2.0             1.0
# 3.0                                   2.0                3.0             2.0
# 5.0                                   3.0                4.0             4.0

# %% [markdown]
# Hemos calculado la mediana de cada indice que no sea Freedom in the world, pues ésta sólo tiene 1 valor perdido:

# %%
DF.info() #206 buenos de 207
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 5 columns):
# Country                   205 non-null object
# FreedomintheWorld         204 non-null float64
# IndexofEconomicFreedom    180 non-null float64
# PressFreedomIndex         189 non-null float64
# DemocracyIndex            167 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 8.1+ KB

# %%
# o
DF.isnull().sum()
# Out:
# Country                    0
# FreedomintheWorld          1
# IndexofEconomicFreedom    25
# PressFreedomIndex         16
# DemocracyIndex            38
# dtype: int64

# %%
import numpy as np

for h in headers[2:]:
    DF[h].fillna(DF.groupby(["FreedomintheWorld"])[h].transform(np.median), inplace=True)

# %% [markdown]
# Obteniendo:

# %%
DF.head(20)
# Out:
#                 Country  FreedomintheWorld  IndexofEconomicFreedom  \
# 0           Afghanistan                1.0                     2.0
# 1               Albania                3.0                     3.0
# 2               Algeria                1.0                     1.0
# 3               Andorra                5.0                     3.0
# 4                Angola                1.0                     2.0
# 5   Antigua and Barbuda                5.0                     3.0
# 6             Argentina                5.0                     2.0
# 7               Armenia                3.0                     3.0
# 8             Australia                5.0                     5.0
# 9               Austria                5.0                     4.0
# 10           Azerbaijan                1.0                     3.0
# 11              Bahamas                5.0                     3.0
# 12              Bahrain                1.0                     3.0
# 13           Bangladesh                3.0                     2.0
# 14             Barbados                5.0                     3.0
# 15              Belarus                1.0                     2.0
# 16              Belgium                5.0                     3.0
# 17               Belize                5.0                     2.0
# 18                Benin                5.0                     2.0
# 19               Bhutan                3.0                     3.0
#
#     PressFreedomIndex  DemocracyIndex
# 0                 2.0             1.0
# 1                 3.0             2.0
# 2                 2.0             1.0
# 3                 4.0             4.0
# 4                 3.0             1.0
# 5                 3.0             4.0
# 6                 3.0             4.0
# 7                 3.0             2.0
# 8                 4.0             5.0
# 9                 4.0             5.0
# 10                1.0             1.0
# 11                3.0             4.0
# 12                1.0             1.0
# 13                2.0             2.0
# 14                3.0             4.0
# 15                2.0             1.0
# 16                5.0             4.0
# 17                3.0             4.0
# 18                3.0             2.0
# 19                3.0             2.0

# %% [markdown]
# Un detalle pequeño es enviar esta data con buenos nombres de columnas:

# %%
DF.columns=["Country","WorldFreedom","EconomicFreedom","PressFreedom","Democracy"]

# %% [markdown]
# **Guardando archivo**
#
# A esta altura es bueno guardar el archivo, pues ya está listo:

# %%
DF.to_csv("indexes.csv",index=None)

# %% [markdown]
# Traigamos la data de los departamentos de Colombia que vimos al final de la unidad anterior:

# %%
idhCol2='https://es.wikipedia.org/wiki/Anexo:Departamentos_de_Colombia_por_IDH'
idhColT2=pd.read_html(idhCol2,header=0,flavor='bs4',attrs={'class': 'sortable',},
                       thousands='\xa0', decimal=',')[0]
idhColT2.iloc[:,2]=idhColT2.iloc[:,2].str.replace("\s","")
idhColT2.columns=[element.split('[')[0].replace(" ","") for element in idhColT2.columns]
idhColT2.Entidad=[element.split('[')[0] for element in idhColT2.Entidad]
newRows=['Amazonas', 'Guainia', 'Guaviare', 'Vaupés', 'Vichada']
info=idhColT2[idhColT2.Entidad=='Región Amazónica'].values.tolist()[0][1:]
newData = pd.DataFrame([[row] + info for row in newRows], columns=idhColT2.columns)
idhColT2=idhColT2.append(newData,ignore_index=True)
idhColT2.drop([0,24,29],inplace=True)
numericos=list(idhColT2.IDH)
numericos.extend(list(idhColT2.Población))

inapropiados=[]
for n in numericos:
    try:
        float(n)
    except ValueError:
        if not n in inapropiados: # evitar duplicados
            inapropiados.append(n)
idhColT2.replace(inapropiados,value=[None]*len(inapropiados),inplace=True)
idhColT2.reset_index(drop=True,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-3dae73569343> in <module>()
#       6 idhColT2.Entidad=[element.split('[')[0] for element in idhColT2.Entidad]
#       7 newRows=['Amazonas', 'Guainia', 'Guaviare', 'Vaupés', 'Vichada']
# ----> 8 info=idhColT2[idhColT2.Entidad=='Región Amazónica'].values.tolist()[0][1:]
#       9 newData = pd.DataFrame([[row] + info for row in newRows], columns=idhColT2.columns)
#      10 idhColT2=idhColT2.append(newData,ignore_index=True)
#
# IndexError: list index out of range

# %% [markdown]
# Así que actualmente, tenemos:

# %%
idhColT2

# %% [markdown]
# Aquí el problema es distinto. Los datos faltantes necesitamos reemplazarlos, no estimarlos. Es decir, hay que traer la data de otro sitio.

# %%
import IPython

pobCol='https://es.wikipedia.org/wiki/Anexo:Departamentos_de_Colombia_por_poblaci%C3%B3n'
iframe = '<iframe src=' + pobCol + ' width=700 height=350></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=https://es.wikipedia.org/wiki/Anexo:Departamentos_de_Colombia_por_poblaci%C3%B3n width=700 height=350></iframe>

# %%
colPOB=pd.read_html(pobCol,header=0,flavor='bs4',attrs={'class': 'sortable',},
                       thousands='\xa0', decimal=',')[0]

# q ha venido?
colPOB.dtypes
# Out:
# N.º                   float64
# Departamento           object
# Población Cabecera      int64
# Población Resto         int64
# Población Total         int64
# dtype: object

# %%
colPOB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
# N.º                   33 non-null float64
# Departamento          34 non-null object
# Población Cabecera    34 non-null int64
# Población Resto       34 non-null int64
# Población Total       34 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# Recuerda que tenemos 32 regiones, es decir aquí ha venido algo extra: Bogotá y Colombia:

# %%
colPOB[colPOB.Departamento.isin (['Colombia','Bogotá','Cundinamarca'])]
# Out:
#     N.º  Departamento  Población Cabecera  Población Resto  Población Total
# 0   1.0        Bogotá             8164178            16869          8181047
# 3   4.0  Cundinamarca             1906623           897615          2804238
# 33  NaN      Colombia            38295351         11538889         49834727

# %% [markdown]
# De aquí, vemos que a la info de Cundinamarca debe sumarsele la de Bogotá, y eliminar luego Bogotá y Colombia.

# %%
colPOB.iloc[3,2:]=colPOB.iloc[3,2:]+colPOB.iloc[0,2:]

# %%
colPOB.drop([0,33],inplace=True)
colPOB.reset_index(drop=True,inplace=True)

# %%
# asi queda:
colPOB
# Out:
#      N.º              Departamento  Población Cabecera  Población Resto  \
# 0    2.0                 Antioquia             5262135          1428842
# 1    3.0           Valle del Cauca             4169228           586472
# 2    4.0              Cundinamarca            10070801           914484
# 3    5.0                 Atlántico             2438772           107366
# 4    6.0                   Bolívar             1693970           477588
# 5    7.0                 Santander             1588034           502820
# 6    8.0                    Nariño              907725           901576
# 7    9.0                   Córdoba              950230           838418
# 8   10.0                    Tolima              980713           439244
# 9   11.0                     Cauca              567610           848535
# 10  12.0        Norte de Santander             1099486           291880
# 11  13.0                 Magdalena              967710           330852
# 12  14.0                    Boyacá              742726           539253
# 13  15.0                     Huila              714762           482287
# 14  16.0                     Cesar              805211           260426
# 15  17.0                La Guajira              570518           469675
# 16  18.0                      Meta              775621           241051
# 17  19.0                    Caldas              719730           274140
# 18  20.0                 Risaralda              761660           206120
# 19  21.0                     Sucre              596618           280406
# 20  22.0                   Quindío              506238            68722
# 21  23.0                     Chocó              253092           262074
# 22  24.0                   Caquetá              300040           196222
# 23  25.0                  Casanare              281609            93649
# 24  26.0                  Putumayo              179323           179573
# 25  27.0                    Arauca              172650            98058
# 26  28.0                  Guaviare               69723            46106
# 27  29.0                  Amazonas               29009            49821
# 28  30.0  San Andrés y Providencia               56487            21926
# 29  31.0                   Vichada               34200            43076
# 30  32.0                    Vaupés               17679            27249
# 31  33.0                   Guainía               13090            30356
#
#     Población Total
# 0           6690977
# 1           4755760
# 2          10985285
# 3           2546138
# 4           2171558
# 5           2090854
# 6           1809301
# 7           1788648
# 8           1419957
# 9           1416145
# 10          1391366
# 11          1298562
# 12          1281979
# 13          1197049
# 14          1065637
# 15          1040193
# 16          1016672
# 17           993870
# 18           967780
# 19           877024
# 20           574960
# 21           515166
# 22           496262
# 23           375258
# 24           358896
# 25           270708
# 26           115829
# 27            78830
# 28            78413
# 29            77276
# 30            44928
# 31            43446

# %% [markdown]
# Preparemonos para llevar esta info a la data anterior.
#
# Eliminemos cosas innecesarias. La primera columna (No) no es necesaria:

# %%
colPOB.drop(['N.º'], axis=1,inplace=True)

# %% [markdown]
# En la data con el IDH por provincia, Población y PaísComparable tampoco son necesarias:

# %%
idhColT2.drop(['Población','PaísComparable'], axis=1,inplace=True)

# %% [markdown]
# Ambas datas tienen el mismo tamaño?

# %%
len(colPOB)==len(idhColT2)
# Out:
# False

# %% [markdown]
# Si es así, la unión de ambas debería ser igual, considerando lo que hemos hecho, pero siempre hay detalles que faltan:

# %%
test=idhColT2.merge(colPOB,left_on='Entidad',right_on='Departamento',how='outer')
test
# Out:
#                      Entidad    IDH              Departamento  \
# 0                     Bogotá  0.792                       NaN
# 1            Valle del Cauca  0.771           Valle del Cauca
# 2   San Andrés y Providencia  0.770  San Andrés y Providencia
# 3                  Atlántico  0.766                 Atlántico
# 4                    Quindío  0.765                   Quindío
# 5                       Meta  0.758                      Meta
# 6                  Santander  0.758                 Santander
# 7                     Caldas  0.757                    Caldas
# 8               Cundinamarca  0.754              Cundinamarca
# 9                  Antioquia  0.752                 Antioquia
# 10                 Risaralda  0.742                 Risaralda
# 11                    Boyacá  0.740                    Boyacá
# 12                  Guaviare  0.737                  Guaviare
# 13                   Bolívar  0.736                   Bolívar
# 14                   Vichada  0.735                   Vichada
# 15                  Casanare  0.730                  Casanare
# 16        Norte de Santander  0.730        Norte de Santander
# 17                    Tolima  0.727                    Tolima
# 18                     Sucre  0.725                     Sucre
# 19                    Arauca  0.722                    Arauca
# 20                     Cesar  0.712                     Cesar
# 21                     Huila  0.709                     Huila
# 22                 Magdalena  0.709                 Magdalena
# 23                    Nariño  0.704                    Nariño
# 24                     Cauca  0.702                     Cauca
# 25                  Amazonas  0.701                  Amazonas
# 26                   Caquetá  0.701                   Caquetá
# 27                   Córdoba  0.699                   Córdoba
# 28                  Putumayo  0.699                  Putumayo
# 29                     Chocó  0.679                     Chocó
# 30                La Guajira  0.678                La Guajira
# 31                   Guainía  0.654                   Guainía
# 32                    Vaupés  0.624                    Vaupés
# 33                  Colombia  0.748                       NaN
#
#     Población Cabecera  Población Resto  Población Total
# 0                  NaN              NaN              NaN
# 1            4169228.0         586472.0        4755760.0
# 2              56487.0          21926.0          78413.0
# 3            2438772.0         107366.0        2546138.0
# 4             506238.0          68722.0         574960.0
# 5             775621.0         241051.0        1016672.0
# 6            1588034.0         502820.0        2090854.0
# 7             719730.0         274140.0         993870.0
# 8           10070801.0         914484.0       10985285.0
# 9            5262135.0        1428842.0        6690977.0
# 10            761660.0         206120.0         967780.0
# 11            742726.0         539253.0        1281979.0
# 12             69723.0          46106.0         115829.0
# 13           1693970.0         477588.0        2171558.0
# 14             34200.0          43076.0          77276.0
# 15            281609.0          93649.0         375258.0
# 16           1099486.0         291880.0        1391366.0
# 17            980713.0         439244.0        1419957.0
# 18            596618.0         280406.0         877024.0
# 19            172650.0          98058.0         270708.0
# 20            805211.0         260426.0        1065637.0
# 21            714762.0         482287.0        1197049.0
# 22            967710.0         330852.0        1298562.0
# 23            907725.0         901576.0        1809301.0
# 24            567610.0         848535.0        1416145.0
# 25             29009.0          49821.0          78830.0
# 26            300040.0         196222.0         496262.0
# 27            950230.0         838418.0        1788648.0
# 28            179323.0         179573.0         358896.0
# 29            253092.0         262074.0         515166.0
# 30            570518.0         469675.0        1040193.0
# 31             13090.0          30356.0          43446.0
# 32             17679.0          27249.0          44928.0
# 33                 NaN              NaN              NaN

# %% [markdown]
# Nuestro test nos muestra quienes no concuerdan para el __merge__:

# %%
test[pd.isnull(test.IDH) | pd.isnull(test.Departamento)]
# Out:
#      Entidad    IDH Departamento  Población Cabecera  Población Resto  \
# 0     Bogotá  0.792          NaN                 NaN              NaN
# 33  Colombia  0.748          NaN                 NaN              NaN
#
#     Población Total
# 0               NaN
# 33              NaN

# %% [markdown]
# Arriba se nota por que no hubo una combinación perfecta. Resolvamos y re hagamos:

# %%
idhColT2[idhColT2.Entidad.isin(['San Andrés', 'Guainia'])]
# Out:
# Empty DataFrame
# Columns: [Entidad, IDH]
# Index: []

# %%
colPOB[colPOB.Departamento.isin(['San Andrés y Providencia', 'Guainía'])]
# Out:
#                 Departamento  Población Cabecera  Población Resto  \
# 28  San Andrés y Providencia               56487            21926
# 31                   Guainía               13090            30356
#
#     Población Total
# 28            78413
# 31            43446

# %%
idhColT2.loc[8, 'Entidad']=colPOB.loc[28, 'Departamento']
idhColT2.loc[28, 'Entidad']=colPOB.loc[31, 'Departamento']

# %% [markdown]
# Ahora debe estar bien:

# %%
idhColT2.merge(colPOB,left_on='Entidad',right_on='Departamento',how='outer')
# Out:
#                      Entidad    IDH              Departamento  \
# 0                     Bogotá  0.792                       NaN
# 1            Valle del Cauca  0.771           Valle del Cauca
# 2   San Andrés y Providencia  0.770  San Andrés y Providencia
# 3   San Andrés y Providencia  0.754  San Andrés y Providencia
# 4                  Atlántico  0.766                 Atlántico
# 5                    Quindío  0.765                   Quindío
# 6                       Meta  0.758                      Meta
# 7                  Santander  0.758                 Santander
# 8                     Caldas  0.757                    Caldas
# 9                  Antioquia  0.752                 Antioquia
# 10                 Risaralda  0.742                 Risaralda
# 11                    Boyacá  0.740                    Boyacá
# 12                  Guaviare  0.737                  Guaviare
# 13                   Bolívar  0.736                   Bolívar
# 14                   Vichada  0.735                   Vichada
# 15                  Casanare  0.730                  Casanare
# 16        Norte de Santander  0.730        Norte de Santander
# 17                    Tolima  0.727                    Tolima
# 18                     Sucre  0.725                     Sucre
# 19                    Arauca  0.722                    Arauca
# 20                     Cesar  0.712                     Cesar
# 21                     Huila  0.709                     Huila
# 22                 Magdalena  0.709                 Magdalena
# 23                    Nariño  0.704                    Nariño
# 24                     Cauca  0.702                     Cauca
# 25                  Amazonas  0.701                  Amazonas
# 26                   Caquetá  0.701                   Caquetá
# 27                   Córdoba  0.699                   Córdoba
# 28                   Guainía  0.699                   Guainía
# 29                   Guainía  0.654                   Guainía
# 30                     Chocó  0.679                     Chocó
# 31                La Guajira  0.678                La Guajira
# 32                    Vaupés  0.624                    Vaupés
# 33                  Colombia  0.748                       NaN
# 34                       NaN    NaN              Cundinamarca
# 35                       NaN    NaN                  Putumayo
#
#     Población Cabecera  Población Resto  Población Total
# 0                  NaN              NaN              NaN
# 1            4169228.0         586472.0        4755760.0
# 2              56487.0          21926.0          78413.0
# 3              56487.0          21926.0          78413.0
# 4            2438772.0         107366.0        2546138.0
# 5             506238.0          68722.0         574960.0
# 6             775621.0         241051.0        1016672.0
# 7            1588034.0         502820.0        2090854.0
# 8             719730.0         274140.0         993870.0
# 9            5262135.0        1428842.0        6690977.0
# 10            761660.0         206120.0         967780.0
# 11            742726.0         539253.0        1281979.0
# 12             69723.0          46106.0         115829.0
# 13           1693970.0         477588.0        2171558.0
# 14             34200.0          43076.0          77276.0
# 15            281609.0          93649.0         375258.0
# 16           1099486.0         291880.0        1391366.0
# 17            980713.0         439244.0        1419957.0
# 18            596618.0         280406.0         877024.0
# 19            172650.0          98058.0         270708.0
# 20            805211.0         260426.0        1065637.0
# 21            714762.0         482287.0        1197049.0
# 22            967710.0         330852.0        1298562.0
# 23            907725.0         901576.0        1809301.0
# 24            567610.0         848535.0        1416145.0
# 25             29009.0          49821.0          78830.0
# 26            300040.0         196222.0         496262.0
# 27            950230.0         838418.0        1788648.0
# 28             13090.0          30356.0          43446.0
# 29             13090.0          30356.0          43446.0
# 30            253092.0         262074.0         515166.0
# 31            570518.0         469675.0        1040193.0
# 32             17679.0          27249.0          44928.0
# 33                 NaN              NaN              NaN
# 34          10070801.0         914484.0       10985285.0
# 35            179323.0         179573.0         358896.0

# %% [markdown]
# Hagamos el merge y eliminemos Entidad:

# %%
idhColFinal=idhColT2.merge(colPOB,left_on='Entidad',right_on='Departamento',how='outer')
idhColFinal.drop(['Entidad'],axis=1,inplace=True)
idhColFinal
# Out:
#       IDH              Departamento  Población Cabecera  Población Resto  \
# 0   0.792                       NaN                 NaN              NaN
# 1   0.771           Valle del Cauca           4169228.0         586472.0
# 2   0.770  San Andrés y Providencia             56487.0          21926.0
# 3   0.754  San Andrés y Providencia             56487.0          21926.0
# 4   0.766                 Atlántico           2438772.0         107366.0
# 5   0.765                   Quindío            506238.0          68722.0
# 6   0.758                      Meta            775621.0         241051.0
# 7   0.758                 Santander           1588034.0         502820.0
# 8   0.757                    Caldas            719730.0         274140.0
# 9   0.752                 Antioquia           5262135.0        1428842.0
# 10  0.742                 Risaralda            761660.0         206120.0
# 11  0.740                    Boyacá            742726.0         539253.0
# 12  0.737                  Guaviare             69723.0          46106.0
# 13  0.736                   Bolívar           1693970.0         477588.0
# 14  0.735                   Vichada             34200.0          43076.0
# 15  0.730                  Casanare            281609.0          93649.0
# 16  0.730        Norte de Santander           1099486.0         291880.0
# 17  0.727                    Tolima            980713.0         439244.0
# 18  0.725                     Sucre            596618.0         280406.0
# 19  0.722                    Arauca            172650.0          98058.0
# 20  0.712                     Cesar            805211.0         260426.0
# 21  0.709                     Huila            714762.0         482287.0
# 22  0.709                 Magdalena            967710.0         330852.0
# 23  0.704                    Nariño            907725.0         901576.0
# 24  0.702                     Cauca            567610.0         848535.0
# 25  0.701                  Amazonas             29009.0          49821.0
# 26  0.701                   Caquetá            300040.0         196222.0
# 27  0.699                   Córdoba            950230.0         838418.0
# 28  0.699                   Guainía             13090.0          30356.0
# 29  0.654                   Guainía             13090.0          30356.0
# 30  0.679                     Chocó            253092.0         262074.0
# 31  0.678                La Guajira            570518.0         469675.0
# 32  0.624                    Vaupés             17679.0          27249.0
# 33  0.748                       NaN                 NaN              NaN
# 34    NaN              Cundinamarca          10070801.0         914484.0
# 35    NaN                  Putumayo            179323.0         179573.0
#
#     Población Total
# 0               NaN
# 1         4755760.0
# 2           78413.0
# 3           78413.0
# 4         2546138.0
# 5          574960.0
# 6         1016672.0
# 7         2090854.0
# 8          993870.0
# 9         6690977.0
# 10         967780.0
# 11        1281979.0
# 12         115829.0
# 13        2171558.0
# 14          77276.0
# 15         375258.0
# 16        1391366.0
# 17        1419957.0
# 18         877024.0
# 19         270708.0
# 20        1065637.0
# 21        1197049.0
# 22        1298562.0
# 23        1809301.0
# 24        1416145.0
# 25          78830.0
# 26         496262.0
# 27        1788648.0
# 28          43446.0
# 29          43446.0
# 30         515166.0
# 31        1040193.0
# 32          44928.0
# 33              NaN
# 34       10985285.0
# 35         358896.0

# %% [markdown]
# Hemos visto que el lenguaje español añade pequeñas complejidades, pues usa tildes. Creemos una columna _normalizada_ extra con el nombre del departamento:

# %%
#instalar unidecode
from unidecode import unidecode as notilde
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-7bcf5082cce7> in <module>()
#       1 #instalar unidecode
# ----> 2 from unidecode import unidecode as notilde
#
# ModuleNotFoundError: No module named 'unidecode'

# %%
byeTilde=lambda x: x if x is None else notilde(x)
idhColFinal[['DepartamentoNorm']]=idhColFinal[['Departamento']].applymap(byeTilde)
#
idhColFinal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-59da14d845d0> in <module>()
#       1 byeTilde=lambda x: x if x is None else notilde(x)
# ----> 2 idhColFinal[['DepartamentoNorm']]=idhColFinal[['Departamento']].applymap(byeTilde)
#       3 #
#       4 idhColFinal
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in applymap(self, func)
#    6060             return lib.map_infer(x.astype(object).values, func)
#    6061
# -> 6062         return self.apply(infer)
#    6063
#    6064     # ----------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in infer(x)
#    6058             if x.empty:
#    6059                 return lib.map_infer(x, func)
# -> 6060             return lib.map_infer(x.astype(object).values, func)
#    6061
#    6062         return self.apply(infer)
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-53-59da14d845d0> in <lambda>(x)
# ----> 1 byeTilde=lambda x: x if x is None else notilde(x)
#       2 idhColFinal[['DepartamentoNorm']]=idhColFinal[['Departamento']].applymap(byeTilde)
#       3 #
#       4 idhColFinal
#
# NameError: ("name 'notilde' is not defined", 'occurred at index Departamento')

# %% [markdown]
# Al igual que en el caso anterior, debemos a esta altura guardar nuestro archivo:

# %%
idhColFinal.to_csv("colombia.csv",index=None)

# %% [markdown]
# _____
#
# **AUSPICIO**:
#
# * El desarrollo de estos contenidos ha sido posible gracias al grant del Berkeley Initiative for Transparency in the Social Sciences (BITSS) at the Center for Effective Global Action (CEGA) at the University of California, Berkeley
#
#
# <center>
# <img src="https://www.bitss.org/wp-content/uploads/2015/07/bitss-55a55026v1_site_icon.png" style="width: 200px;"/>
# </center>
#
# * Este curso cuenta con el auspicio de:
#
#
# <center>
# <img src="https://www.python.org/static/img/psf-logo@2x.png" style="width: 500px;"/>
# </center>
#
#
#
# **RECONOCIMIENTO**
#
#
# EL Dr. Magallanes agradece a la Pontificia Universidad Católica del Perú, por su apoyo en la participación en la Escuela ALACIP.
#
# <center>
# <img src="https://dci.pucp.edu.pe/wp-content/uploads/2014/02/Logotipo_colores-290x145.jpg" style="width: 400px;"/>
# </center>
#
#
# El autor reconoce el apoyo que el eScience Institute de la Universidad de Washington le ha brindado desde el 2015 para desarrollar su investigación en Ciencia de Datos.
#
# <center>
# <img src="https://escience.washington.edu/wp-content/uploads/2015/10/eScience_Logo_HR.png" style="width: 500px;"/>
# </center>
#
# <br>
# <br>
